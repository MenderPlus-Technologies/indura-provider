# %% [markdown]
# # Dev Notes
#
# - Subscriptions table status must use `derivedStatusLabel` from `/providers/subscriptions` when present.
# - Fallback to `deriveSubscriptionStatus` only if no label is provided.
